# %% [markdown]
# <a href="https://colab.research.google.com/github/mahmoudzaid/mahmoud-zaid/blob/main/Video_Game_Sales_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'drive/My Drive/Colab Notebooks/EFE Final Project/data/vgsales.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %%
# Get the dataset information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
# Check for the null values in all the columns.
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Remove the rows/columns containing the null values.
df= df.dropna()

# %%
# Convert the data-type of the year values into integer values.
df['Year'] = df['Year'].astype(int)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16291 rows x 11 columns]

# %%
# Find out the total number of units sold yearly across different regions and the world.
df.iloc[:,[6,7,8,9,10]].sum()
# Out:
# NA_Sales        4327.65
# EU_Sales        2406.69
# JP_Sales        1284.27
# Other_Sales      788.91
# Global_Sales    8811.97
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
# Create line plots for genre-wise total number of units sold across different regions and the world.
genre  = df.groupby(by = 'Genre')
sum = genre.agg(func = 'sum')
for i in sum.columns[2:]:
  plt.figure(figsize = (19, 7))
  plt.plot(sum.index, sum[i])
  plt.show()

# %%
# What genre of video game is most popular in Japan in terms of the total number of units sold?
popular = df.iloc[:,[4,8]].sort_values(by = 'JP_Sales',ascending = False)
popular.iloc[0,:]
# Out:
# Genre       Role-Playing
# JP_Sales           10.22
# Name: 4, dtype: object

# %%
# Genre-wise total number of units sold across different regions and the world in descending order.
df.iloc[:,[4,10]].sort_values(by = 'Global_Sales',ascending = False)
# Out:
#               Genre  Global_Sales
# 0            Sports         82.74
# 1          Platform         40.24
# 2            Racing         35.82
# 3            Sports         33.00
# 4      Role-Playing         31.37
# ...             ...           ...
# 16183     Adventure          0.01
# 16184      Fighting          0.01
# 16185     Adventure          0.01
# 16186      Strategy          0.01
# 16597      Platform          0.01
#
# [16291 rows x 2 columns]

# %%
gen = df.iloc[:,[4,10]].sort_values(by = 'Global_Sales',ascending = False)
gen.iloc[0,:]
# Out:
# Genre           Sports
# Global_Sales     82.74
# Name: 0, dtype: object

# %%
# Find out the publisher-wise total number of units sold across different regions and the world in the descending order.
df.iloc[:,[5,10]].sort_values(by = 'Global_Sales',ascending = False)
# Out:
#               Publisher  Global_Sales
# 0              Nintendo         82.74
# 1              Nintendo         40.24
# 2              Nintendo         35.82
# 3              Nintendo         33.00
# 4              Nintendo         31.37
# ...                 ...           ...
# 16183    Kadokawa Games          0.01
# 16184      SNK Playmore          0.01
# 16185  Arc System Works          0.01
# 16186   Electronic Arts          0.01
# 16597           Wanadoo          0.01
#
# [16291 rows x 2 columns]

# %%
publisher = df.iloc[:,[5,10]].sort_values(by = 'Global_Sales',ascending = False)
publisher.iloc[0,:]
# Out:
# Publisher       Nintendo
# Global_Sales       82.74
# Name: 0, dtype: object

# %%
# Find out the platform-wise the total number of units sold across different regions and the world in the descending order.
df.iloc[:,[2,10]].sort_values(by = 'Global_Sales',ascending = False)
# Out:
#       Platform  Global_Sales
# 0          Wii         82.74
# 1          NES         40.24
# 2          Wii         35.82
# 3          Wii         33.00
# 4           GB         31.37
# ...        ...           ...
# 16183      PSP          0.01
# 16184      PS2          0.01
# 16185      PSP          0.01
# 16186       PC          0.01
# 16597      GBA          0.01
#
# [16291 rows x 2 columns]
